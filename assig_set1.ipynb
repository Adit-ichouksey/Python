# %%
input_set = {1,2,3,4,5}
output_set = {x+3 for x in input_set}
print(output_set)
# Out:
# {4, 5, 6, 7, 8}

# %%
x=[10,20,30,40]
result =[x + 20 for x in x]
print(result)
# Out:
# [30, 40, 50, 60]

# %%
s1={1,2,3}
s2={1,2,3,4,5}
print(s1.union(s2))
# Out:
# {1, 2, 3, 4, 5}

# %%
x=[2,4,6]
result = [x-1 for x in x]
print(result)
# Out:
# [1, 3, 5]

# %%
S1={1,2}
S2={2,3}
S3={3,4}
result=(S1.union(S2).union(S3))
print(result)
# Out:
# {1, 2, 3, 4}

# %%
x={10,20,30}
result = [x+10 for x in x]
print(result)
# Out:
# [20, 30, 40]

# %%
S={1,2,3,4,5}
n=3
S.discard(n)
print(S)
# Out:
# {1, 2, 4, 5}
